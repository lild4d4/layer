# %%
diff = [127425,127427,127431,127433,127435,127437,127439,127443,127443,127445,127447,127451,127453,127455,127457,127459,127463,127465,127467,127469,127471,127475,127477,127479,127481,127483,127487,127489,127491,127493,127495,127499,127501,127503,127505,127509,127511,127513,127515,127517,127521,127523,127525,127527,127529,127533,127535,127537,127539]


for d in range(1, len(diff)):
    print(diff[d] - diff[d-1])
# Out:
# 2
# 4
# 2
# 2
# 2
# 2
# 4
# 0
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
